# %% [markdown]
# # Python Oanda API v20

# %% [markdown]
# Python Wrapper developed by [Feite Brekeveld](https://github.com/hootnot/oanda-api-v20)
#
# [Python Oanda REST API v20 Document](https://buildmedia.readthedocs.org/media/pdf/oanda-api-v20/latest/oanda-api-v20.pdf)
#
# Jupyter Notebook inspired by lessons from Anthony Ng at [Skillshare](https://www.skillshare.com/classes/Python-Algo-Trading-FX-Trading-with-Oanda/2024083035?via=search-layout-grid)

# %% [markdown]
# # Package Management

# %%
# !pip3 -q install oandapyV20

# %%
import os
from pandas import DataFrame, Series
from configparser import ConfigParser
from oandapyV20 import API

# %% [markdown]
# # Credential Management
#
# ## Account ID
# https://www.oanda.com/demo-account/tpa/manage
#
# ## Access Token
# https://www.oanda.com/demo-account/tpa/personal_token

# %% [markdown]
# ## Configuration File
#
# AccountID and access token are saved in a separated configuration file for security and convenience.

# %%
config_file = 'oanda-v20-auth.conf'

if not os.path.isfile(config_file):
    print('please create a configuration file: ' + config_file)
else:
    config = ConfigParser()
    config.read(config_file)
    accountID = config['oanda']['accountID']
    access_token = config['oanda']['access_token']
    api = API(access_token)

# %% [markdown]
# # API Request

# %% [markdown]
# ## Account Info
# [Oanda API - Account](https://developer.oanda.com/rest-live-v20/account-ep/)
#
# [Python-Oanda API-Account](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/accounts.html)

# %%
from oandapyV20.endpoints.accounts import AccountList, AccountDetails, AccountSummary
from oandapyV20.endpoints.accounts import AccountInstruments

# %% [markdown]
# ### Account List
# [Python-Oanda API - Account List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/accounts/accountlist.html)

# %%
r = api.request(AccountList())
r
# Out:
# {'accounts': [{'id': '101-011-13528713-001', 'tags': []}]}

# %%
accountID = r['accounts'][0]['id']
accountID
# Out:
# '101-011-13528713-001'

# %% [markdown]
# ### Account Details
#
# [Python - Oanda API - Account Details](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/accounts/accountdetails.html)

# %%
r = api.request(AccountDetails(accountID))
Series(r['account'])
# Out:
# guaranteedStopLossOrderMode                                             DISABLED
# hedgingEnabled                                                             False
# id                                                          101-011-13528713-001
# createdTime                                       2020-02-21T21:09:09.769110943Z
# currency                                                                     USD
# createdByUserID                                                         13528713
# alias                                                                    Primary
# marginRate                                                                  0.02
# lastTransactionID                                                              9
# balance                                                              100000.0000
# openTradeCount                                                                 1
# openPositionCount                                                              1
# pendingOrderCount                                                              1
# pl                                                                        0.0000
# resettablePL                                                              0.0000
# resettablePLTime                                                               0
# financing                                                                 0.0000
# commission                                                                0.0000
# dividendAdjustment                                                             0
# guaranteedExecutionFees                                                   0.0000
# orders                         [{'id': '8', 'createTime': '2020-02-21T21:53:5...
# positions                      [{'instrument': 'EUR_USD', 'long': {'units': '...
# trades                         [{'id': '5', 'instrument': 'EUR_USD', 'price':...
# unrealizedPL                                                             -0.0001
# NAV                                                                   99999.9999
# marginUsed                                                                0.0217
# marginAvailable                                                       99999.9782
# positionValue                                                             1.0847
# marginCloseoutUnrealizedPL                                                0.0000
# marginCloseoutNAV                                                    100000.0000
# marginCloseoutMarginUsed                                                  0.0217
# marginCloseoutPositionValue                                               1.0847
# marginCloseoutPercent                                                    0.00000
# withdrawalLimit                                                       99999.9782
# marginCallMarginUsed                                                      0.0217
# marginCallPercent                                                        0.00000
# dtype: object

# %% [markdown]
# ### Account Summary
# [Python-Oanda API - Account Summary](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/accounts/accountsummary.html)

# %%
r = api.request(AccountSummary(accountID))
Series(r['account'])
# Out:
# guaranteedStopLossOrderMode                          DISABLED
# hedgingEnabled                                          False
# id                                       101-011-13528713-001
# createdTime                    2020-02-21T21:09:09.769110943Z
# currency                                                  USD
# createdByUserID                                      13528713
# alias                                                 Primary
# marginRate                                               0.02
# lastTransactionID                                           9
# balance                                           100000.0000
# openTradeCount                                              1
# openPositionCount                                           1
# pendingOrderCount                                           1
# pl                                                     0.0000
# resettablePL                                           0.0000
# resettablePLTime                                            0
# financing                                              0.0000
# commission                                             0.0000
# dividendAdjustment                                          0
# guaranteedExecutionFees                                0.0000
# unrealizedPL                                          -0.0001
# NAV                                                99999.9999
# marginUsed                                             0.0217
# marginAvailable                                    99999.9782
# positionValue                                          1.0847
# marginCloseoutUnrealizedPL                             0.0000
# marginCloseoutNAV                                 100000.0000
# marginCloseoutMarginUsed                               0.0217
# marginCloseoutPositionValue                            1.0847
# marginCloseoutPercent                                 0.00000
# withdrawalLimit                                    99999.9782
# marginCallMarginUsed                                   0.0217
# marginCallPercent                                     0.00000
# dtype: object

# %% [markdown]
# ### Account Instruments
# [Oanda API - Account Instruments](https://developer.oanda.com/rest-live-v20/account-ep/)
#
# [Python-Oanda API - Account Instruments](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/accounts/accountinstruments.html)

# %% [markdown]
# #### Tradeable Instruments

# %%
r = api.request(AccountInstruments(accountID))
DataFrame(r['instruments'])
# Out:
#            name      type   displayName  pipLocation  displayPrecision  \
# 0       XAG_CHF     METAL    Silver/CHF           -4                 5
# 1       XAG_EUR     METAL    Silver/EUR           -4                 5
# 2    UK10YB_GBP       CFD   UK 10Y Gilt           -2                 3
# 3       GBP_ZAR  CURRENCY       GBP/ZAR           -4                 5
# 4     SOYBN_USD       CFD      Soybeans           -2                 3
# ..          ...       ...           ...          ...               ...
# 121  SPX500_USD       CFD    US SPX 500            0                 1
# 122     SGD_HKD  CURRENCY       SGD/HKD           -4                 5
# 123     XAU_CAD     METAL      Gold/CAD           -2                 3
# 124    MBTC_USD       CFD  Mini Bitcoin           -2                 3
# 125     USD_CNH  CURRENCY       USD/CNH           -4                 5
#
#      tradeUnitsPrecision minimumTradeSize maximumTrailingStopDistance  \
# 0                      0                1                     1.00000
# 1                      0                1                     1.00000
# 2                      0                1                     100.000
# 3                      0                1                     1.00000
# 4                      0                1                     100.000
# ..                   ...              ...                         ...
# 121                    0                1                     10000.0
# 122                    0                1                     1.00000
# 123                    0                1                     100.000
# 124                    0                1                     100.000
# 125                    0                1                     1.00000
#
#     minimumTrailingStopDistance maximumPositionSize maximumOrderUnits  \
# 0                       0.00050                   0            500000
# 1                       0.00050                   0            500000
# 2                         0.050                   0            100000
# 3                       0.00050                   0         100000000
# 4                         0.050                   0            600000
# ..                          ...                 ...               ...
# 121                         5.0                   0             10000
# 122                     0.00050                   0         100000000
# 123                       0.050                   0             20000
# 124                       0.050                   0              1000
# 125                     0.00050                   0         100000000
#
#     marginRate guaranteedStopLossOrderMode  \
# 0         0.05                    DISABLED
# 1         0.05                    DISABLED
# 2         0.02                    DISABLED
# 3         0.05                    DISABLED
# 4     0.033333                    DISABLED
# ..         ...                         ...
# 121       0.02                    DISABLED
# 122        0.1                    DISABLED
# 123       0.02                    DISABLED
# 124        0.5                    DISABLED
# 125       0.05                    DISABLED
#
#                                                tags  \
# 0    [{'type': 'ASSET_CLASS', 'name': 'COMMODITY'}]
# 1    [{'type': 'ASSET_CLASS', 'name': 'COMMODITY'}]
# 2         [{'type': 'ASSET_CLASS', 'name': 'BOND'}]
# 3     [{'type': 'ASSET_CLASS', 'name': 'CURRENCY'}]
# 4    [{'type': 'ASSET_CLASS', 'name': 'COMMODITY'}]
# ..                                              ...
# 121      [{'type': 'ASSET_CLASS', 'name': 'INDEX'}]
# 122   [{'type': 'ASSET_CLASS', 'name': 'CURRENCY'}]
# 123  [{'type': 'ASSET_CLASS', 'name': 'COMMODITY'}]
# 124     [{'type': 'ASSET_CLASS', 'name': 'CRYPTO'}]
# 125   [{'type': 'ASSET_CLASS', 'name': 'CURRENCY'}]
#
#                                              financing
# 0    {'longRate': '-0.0069', 'shortRate': '-0.0173'...
# 1    {'longRate': '-0.0092', 'shortRate': '-0.0147'...
# 2    {'longRate': '-0.038', 'shortRate': '-0.012', ...
# 3    {'longRate': '-0.0919', 'shortRate': '0.0451',...
# 4    {'longRate': '-0.096', 'shortRate': '0.046', '...
# ..                                                 ...
# 121  {'longRate': '-0.0418', 'shortRate': '-0.0082'...
# 122  {'longRate': '-0.0209', 'shortRate': '-0.0206'...
# 123  {'longRate': '-0.0297', 'shortRate': '0.0062',...
# 124  {'longRate': '-0.15', 'shortRate': '0', 'finan...
# 125  {'longRate': '-0.0287', 'shortRate': '0.00090'...
#
# [126 rows x 15 columns]

# %% [markdown]
# #### Specific Instrument

# %%
params = {'instruments':"EUR_USD"}
r = api.request(AccountInstruments(accountID, params))
r
# Out:
# {'instruments': [{'name': 'EUR_USD',
#    'type': 'CURRENCY',
#    'displayName': 'EUR/USD',
#    'pipLocation': -4,
#    'displayPrecision': 5,
#    'tradeUnitsPrecision': 0,
#    'minimumTradeSize': '1',
#    'maximumTrailingStopDistance': '1.00000',
#    'minimumTrailingStopDistance': '0.00050',
#    'maximumPositionSize': '0',
#    'maximumOrderUnits': '100000000',
#    'marginRate': '0.02',
#    'guaranteedStopLossOrderMode': 'DISABLED',
#    'tags': [{'type': 'ASSET_CLASS', 'name': 'CURRENCY'}],
#    'financing': {'longRate': '-0.0326',
#     'shortRate': '0.0119',
#     'financingDaysOfWeek': [{'dayOfWeek': 'MONDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'TUESDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'WEDNESDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'THURSDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'FRIDAY', 'daysCharged': 1},
#      {'dayOfWeek': 'SATURDAY', 'daysCharged': 0},
#      {'dayOfWeek': 'SUNDAY', 'daysCharged': 0}]}}],
#  'lastTransactionID': '9'}

# %% [markdown]
# ## Instruments
# [Oanda-API - Instruments](https://developer.oanda.com/rest-live-v20/instrument-ep/)
#
# [Python-Oanda API-Instruments](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/instruments.html)
#
# - InstrumentsCandles
# - InstrumentsOrderBook
# - InstrumentsPositionBook

# %% [markdown]
# ### Instruments Candles
#
# [Python-Oanda API - InstrumentsCandles](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/instruments/instrumentlist.html)

# %%
from oandapyV20.endpoints.instruments \
import InstrumentsCandles, \
        InstrumentsOrderBook, \
        InstrumentsPositionBook

# %%
params = {
    "count": 5,
    "granularity": "M5"
}
r = api.request(InstrumentsCandles(instrument="EUR_USD", params=params))
r
# Out:
# {'instrument': 'EUR_USD',
#  'granularity': 'M5',
#  'candles': [{'complete': True,
#    'volume': 33,
#    'time': '2020-02-21T21:35:00.000000000Z',
#    'mid': {'o': '1.08488', 'h': '1.08491', 'l': '1.08482', 'c': '1.08488'}},
#   {'complete': True,
#    'volume': 43,
#    'time': '2020-02-21T21:40:00.000000000Z',
#    'mid': {'o': '1.08486', 'h': '1.08488', 'l': '1.08480', 'c': '1.08486'}},
#   {'complete': True,
#    'volume': 90,
#    'time': '2020-02-21T21:45:00.000000000Z',
#    'mid': {'o': '1.08487', 'h': '1.08488', 'l': '1.08470', 'c': '1.08477'}},
#   {'complete': True,
#    'volume': 49,
#    'time': '2020-02-21T21:50:00.000000000Z',
#    'mid': {'o': '1.08478', 'h': '1.08482', 'l': '1.08468', 'c': '1.08482'}},
#   {'complete': True,
#    'volume': 122,
#    'time': '2020-02-21T21:55:00.000000000Z',
#    'mid': {'o': '1.08483', 'h': '1.08525', 'l': '1.08473', 'c': '1.08474'}}]}

# %% [markdown]
# ### InstrumentsOrderBook
# Get orderbook data for a specified Instrument.
#
# [Python-Oanda API - InstrumentsOrderBook](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/instruments/instrumentorderbook.html)

# %%
r = api.request(InstrumentsOrderBook(instrument="EUR_USD"))
r
# Out:
# {'orderBook': {'instrument': 'EUR_USD',
#   'time': '2020-02-22T12:20:00Z',
#   'unixTime': '1582374000',
#   'price': '1.08474',
#   'bucketWidth': '0.00050',
#   'buckets': [{'price': '0.00000',
#     'longCountPercent': '0.2260',
#     'shortCountPercent': '0.1843'},
#    {'price': '0.00050',
#     'longCountPercent': '0.0535',
#     'shortCountPercent': '0.0297'},
#    {'price': '0.00100',
#     'longCountPercent': '0.2973',
#     'shortCountPercent': '0.0208'},
#    {'price': '0.00150',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.00200',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.00250',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.00300',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.00350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.00400',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.00450',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.00500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.00550',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00700',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.00750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.00800',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.00850',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.00900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.01000',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0327'},
#    {'price': '0.01050',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.01200',
#     'longCountPercent': '0.1249',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01250',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.01600',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.01750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.01900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.02000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.02200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.02250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.02300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.02850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.03200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.03550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.04350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.04500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.04800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.05000',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.05100',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.05250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.07150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.07500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.07700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.07800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.08000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08300',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08450',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08500',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.08750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.09000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.09100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.09150',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.09550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.09700',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.09750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.09900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.09950',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.10000',
#     'longCountPercent': '0.0654',
#     'shortCountPercent': '0.0862'},
#    {'price': '0.10250',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.10350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.10750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.10800',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.10950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.11000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.11100',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.11250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.11450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.11550',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.11600',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.11700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.11850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.11900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12000',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.12050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.12100',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12150',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.12300',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.12500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.12550',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12700',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.12800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.12950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.13050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.13200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.13250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.13450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.13600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.13650',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.13750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.13900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14050',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.14100',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.14150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.14850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.14900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.15000',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.15350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.15550',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.15700',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.16450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.16600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.17000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.17200',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.17300',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.17350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.17550',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.17900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.18250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.18750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.18900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.19100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.19450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.19800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.20000',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0268'},
#    {'price': '0.20150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.20200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.20250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.21550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.21700',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.21900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.22450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.23000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.23100',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.23450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.23500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.23600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.23650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.23850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.24350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.24900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.25000',
#     'longCountPercent': '0.0268',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.25550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.25600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.25700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.26000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.27650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.27850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.28300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.29450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.30000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.30500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.30850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.32000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.32750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.33000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.33700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.33900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.34000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.34100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.34200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.36300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.37900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.39350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.40000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.40350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.41100',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.41900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.42300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.42400',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.44100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.44700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.45000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.49150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.49700',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.50000',
#     'longCountPercent': '0.0803',
#     'shortCountPercent': '0.1041'},
#    {'price': '0.50300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.50800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.52000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.52500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.53900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.54000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.54200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.54400',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.54850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.55000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.55500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.55650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.55850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.56000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.56250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.56300',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.56500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0862'},
#    {'price': '0.56550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0178'},
#    {'price': '0.56600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0505'},
#    {'price': '0.56650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0595'},
#    {'price': '0.56700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.57150',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.57450',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.57500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.57850',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.58200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.58500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0208'},
#    {'price': '0.59100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.59400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.59900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.59950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.60000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0297'},
#    {'price': '0.60450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.60650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.60800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.60900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.61250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.61450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.62200',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.62500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.62750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.62850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.62900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.63950',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.64350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.64500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.64600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.64900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.64950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.65000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.65050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.65100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.65300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.65650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.65950',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.66150',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.66300',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.66350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.66500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.66650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.66850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.67000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.67200',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.67250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.67500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.67950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0149'},
#    {'price': '0.68000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0387'},
#    {'price': '0.68050',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0416'},
#    {'price': '0.68100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.68200',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.68400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.68850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.69450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.69950',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.70000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.70250',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.70450',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.70800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71200',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.71500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.71600',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71700',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.71750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.71900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.71950',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.72000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.72050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.72100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.72150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.72200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.72250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.72600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.72800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.72950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.74250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74300',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74350',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74400',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74450',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74500',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74550',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74600',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74650',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74700',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74750',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74800',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74850',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.74900',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.74950',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75000',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.75050',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75100',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75150',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.75200',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75250',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75300',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75350',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75400',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75450',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75500',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.75550',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75600',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75650',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75700',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.75750',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75800',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75850',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75900',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.75950',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76000',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76050',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.76100',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76150',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76200',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76250',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76300',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76350',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76400',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76450',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76500',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76550',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76600',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76650',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76700',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76750',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76800',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76850',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76900',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.76950',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.77250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.77450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.77850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.77900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.78000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.78100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.78200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.78250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.78450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.78600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.78900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.79150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.79200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.79250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79750',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.79950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.80000',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0238'},
#    {'price': '0.80050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.80900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.80950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.81050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.81200',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.81550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0951'},
#    {'price': '0.81600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.1606'},
#    {'price': '0.81650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.1606'},
#    {'price': '0.81700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.1100'},
#    {'price': '0.81750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.1516'},
#    {'price': '0.81800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.81950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0743'},
#    {'price': '0.82050',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.2676'},
#    {'price': '0.82100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0892'},
#    {'price': '0.82250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.82750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.82850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.82950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.83050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.83150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.83200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.83250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.83300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.83350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.83750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.83850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.83950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.84050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.84150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.84200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.84950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85000',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.85600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.85850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.85900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86000',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86050',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.86250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.86350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.86400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.86600',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0089'},
#    {'price': '0.86850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.86900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0119'},
#    {'price': '0.87200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.87300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.87450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.87900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.87950',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88000',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.88250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88300',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.88500',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.88550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.88700',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.88850',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.88900',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.89000',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0178'},
#    {'price': '0.89050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.89200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.89250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.89600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89650',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89800',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89900',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.89950',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90000',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0565'},
#    {'price': '0.90050',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90100',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90150',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90250',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90300',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90350',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90450',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90500',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90550',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0030'},
#    {'price': '0.90600',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0000'},
#    {'price': '0.90650',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90700',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0059'},
#    {'price': '0.90800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.4252'},
#    {'price': '0.90850',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.3954'},
#    {'price': '0.90900',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0922'},
#    {'price': '0.90950',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0238'},
#    {'price': '0.91000',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0268'},
#    {'price': '0.91050',
#     'longCountPercent': '0.0327',
# ...
#    {'price': '1.08150',
#     'longCountPercent': '0.0743',
#     'shortCountPercent': '0.1308'},
#    {'price': '1.08200',
#     'longCountPercent': '0.1487',
#     'shortCountPercent': '0.1160'},
#    {'price': '1.08250',
#     'longCountPercent': '0.1397',
#     'shortCountPercent': '0.2022'},
#    {'price': '1.08300',
#     'longCountPercent': '0.1516',
#     'shortCountPercent': '0.1576'},
#    {'price': '1.08350',
#     'longCountPercent': '0.0862',
#     'shortCountPercent': '0.2319'},
#    {'price': '1.08400',
#     'longCountPercent': '0.1189',
#     'shortCountPercent': '0.0862'},
#    {'price': '1.08450',
#     'longCountPercent': '0.1814',
#     'shortCountPercent': '0.0565'},
#    {'price': '1.08500',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.08550',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.1962'},
#    {'price': '1.08600',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.2557'},
#    {'price': '1.08650',
#     'longCountPercent': '0.2438',
#     'shortCountPercent': '0.3271'},
#    {'price': '1.08700',
#     'longCountPercent': '0.2052',
#     'shortCountPercent': '0.3865'},
#    {'price': '1.08750',
#     'longCountPercent': '0.1160',
#     'shortCountPercent': '0.2141'},
#    {'price': '1.08800',
#     'longCountPercent': '0.1665',
#     'shortCountPercent': '0.3092'},
#    {'price': '1.08850',
#     'longCountPercent': '0.1724',
#     'shortCountPercent': '0.4044'},
#    {'price': '1.08900',
#     'longCountPercent': '0.2052',
#     'shortCountPercent': '0.3122'},
#    {'price': '1.08950',
#     'longCountPercent': '0.1249',
#     'shortCountPercent': '0.1843'},
#    {'price': '1.09000',
#     'longCountPercent': '0.1041',
#     'shortCountPercent': '0.3419'},
#    {'price': '1.09050',
#     'longCountPercent': '0.0862',
#     'shortCountPercent': '0.2587'},
#    {'price': '1.09100',
#     'longCountPercent': '0.0743',
#     'shortCountPercent': '0.2289'},
#    {'price': '1.09150',
#     'longCountPercent': '0.0892',
#     'shortCountPercent': '0.1397'},
#    {'price': '1.09200',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.1873'},
#    {'price': '1.09250',
#     'longCountPercent': '0.0803',
#     'shortCountPercent': '0.2111'},
#    {'price': '1.09300',
#     'longCountPercent': '0.0922',
#     'shortCountPercent': '0.1606'},
#    {'price': '1.09350',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.1279'},
#    {'price': '1.09400',
#     'longCountPercent': '0.0505',
#     'shortCountPercent': '0.1546'},
#    {'price': '1.09450',
#     'longCountPercent': '0.0981',
#     'shortCountPercent': '0.1397'},
#    {'price': '1.09500',
#     'longCountPercent': '0.0535',
#     'shortCountPercent': '0.1695'},
#    {'price': '1.09550',
#     'longCountPercent': '0.1873',
#     'shortCountPercent': '0.1397'},
#    {'price': '1.09600',
#     'longCountPercent': '0.0892',
#     'shortCountPercent': '0.1041'},
#    {'price': '1.09650',
#     'longCountPercent': '0.0654',
#     'shortCountPercent': '0.0684'},
#    {'price': '1.09700',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.1219'},
#    {'price': '1.09750',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0714'},
#    {'price': '1.09800',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.1279'},
#    {'price': '1.09850',
#     'longCountPercent': '0.0684',
#     'shortCountPercent': '0.1695'},
#    {'price': '1.09900',
#     'longCountPercent': '0.0803',
#     'shortCountPercent': '0.2141'},
#    {'price': '1.09950',
#     'longCountPercent': '0.0773',
#     'shortCountPercent': '0.1754'},
#    {'price': '1.10000',
#     'longCountPercent': '0.0743',
#     'shortCountPercent': '0.2557'},
#    {'price': '1.10050',
#     'longCountPercent': '0.0743',
#     'shortCountPercent': '0.0535'},
#    {'price': '1.10100',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.1843'},
#    {'price': '1.10150',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0922'},
#    {'price': '1.10200',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.1130'},
#    {'price': '1.10250',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0654'},
#    {'price': '1.10300',
#     'longCountPercent': '0.0684',
#     'shortCountPercent': '0.1308'},
#    {'price': '1.10350',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0803'},
#    {'price': '1.10400',
#     'longCountPercent': '0.0743',
#     'shortCountPercent': '0.0773'},
#    {'price': '1.10450',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0743'},
#    {'price': '1.10500',
#     'longCountPercent': '0.1011',
#     'shortCountPercent': '0.1784'},
#    {'price': '1.10550',
#     'longCountPercent': '0.0446',
#     'shortCountPercent': '0.0714'},
#    {'price': '1.10600',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0951'},
#    {'price': '1.10650',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0922'},
#    {'price': '1.10700',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0922'},
#    {'price': '1.10750',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0862'},
#    {'price': '1.10800',
#     'longCountPercent': '0.0981',
#     'shortCountPercent': '0.0922'},
#    {'price': '1.10850',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.0981'},
#    {'price': '1.10900',
#     'longCountPercent': '0.0892',
#     'shortCountPercent': '0.3598'},
#    {'price': '1.10950',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.1814'},
#    {'price': '1.11000',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.2735'},
#    {'price': '1.11050',
#     'longCountPercent': '0.1219',
#     'shortCountPercent': '0.1784'},
#    {'price': '1.11100',
#     'longCountPercent': '0.0505',
#     'shortCountPercent': '0.0654'},
#    {'price': '1.11150',
#     'longCountPercent': '0.0535',
#     'shortCountPercent': '0.0862'},
#    {'price': '1.11200',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0773'},
#    {'price': '1.11250',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.1279'},
#    {'price': '1.11300',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.1873'},
#    {'price': '1.11350',
#     'longCountPercent': '0.0922',
#     'shortCountPercent': '0.0892'},
#    {'price': '1.11400',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0803'},
#    {'price': '1.11450',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0862'},
#    {'price': '1.11500',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.0833'},
#    {'price': '1.11550',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0595'},
#    {'price': '1.11600',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.11650',
#     'longCountPercent': '0.1011',
#     'shortCountPercent': '0.0535'},
#    {'price': '1.11700',
#     'longCountPercent': '0.0862',
#     'shortCountPercent': '0.0951'},
#    {'price': '1.11750',
#     'longCountPercent': '0.0714',
#     'shortCountPercent': '0.0595'},
#    {'price': '1.11800',
#     'longCountPercent': '0.0833',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.11850',
#     'longCountPercent': '0.0862',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.11900',
#     'longCountPercent': '0.0714',
#     'shortCountPercent': '0.0505'},
#    {'price': '1.11950',
#     'longCountPercent': '0.0714',
#     'shortCountPercent': '0.0714'},
#    {'price': '1.12000',
#     'longCountPercent': '0.0624',
#     'shortCountPercent': '0.0833'},
#    {'price': '1.12050',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0951'},
#    {'price': '1.12100',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.12150',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0565'},
#    {'price': '1.12200',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0446'},
#    {'price': '1.12250',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0773'},
#    {'price': '1.12300',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0357'},
#    {'price': '1.12350',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0565'},
#    {'price': '1.12400',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.1070'},
#    {'price': '1.12450',
#     'longCountPercent': '0.0892',
#     'shortCountPercent': '0.0922'},
#    {'price': '1.12500',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.1576'},
#    {'price': '1.12550',
#     'longCountPercent': '0.0803',
#     'shortCountPercent': '0.1695'},
#    {'price': '1.12600',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.12650',
#     'longCountPercent': '0.0446',
#     'shortCountPercent': '0.0833'},
#    {'price': '1.12700',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.1070'},
#    {'price': '1.12750',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.1130'},
#    {'price': '1.12800',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0743'},
#    {'price': '1.12850',
#     'longCountPercent': '0.0535',
#     'shortCountPercent': '0.2141'},
#    {'price': '1.12900',
#     'longCountPercent': '0.0505',
#     'shortCountPercent': '0.1070'},
#    {'price': '1.12950',
#     'longCountPercent': '0.0654',
#     'shortCountPercent': '0.1784'},
#    {'price': '1.13000',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0714'},
#    {'price': '1.13050',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0833'},
#    {'price': '1.13100',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0476'},
#    {'price': '1.13150',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0595'},
#    {'price': '1.13200',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0505'},
#    {'price': '1.13250',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.13300',
#     'longCountPercent': '0.0505',
#     'shortCountPercent': '0.0535'},
#    {'price': '1.13350',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0684'},
#    {'price': '1.13400',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0476'},
#    {'price': '1.13450',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0654'},
#    {'price': '1.13500',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0565'},
#    {'price': '1.13550',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0505'},
#    {'price': '1.13600',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0208'},
#    {'price': '1.13650',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0743'},
#    {'price': '1.13700',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0387'},
#    {'price': '1.13750',
#     'longCountPercent': '0.0268',
#     'shortCountPercent': '0.1695'},
#    {'price': '1.13800',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.13850',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.13900',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0387'},
#    {'price': '1.13950',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0981'},
#    {'price': '1.14000',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.14050',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0327'},
#    {'price': '1.14100',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0565'},
#    {'price': '1.14150',
#     'longCountPercent': '0.0624',
#     'shortCountPercent': '0.2914'},
#    {'price': '1.14200',
#     'longCountPercent': '0.0059',
#     'shortCountPercent': '1.0347'},
#    {'price': '1.14250',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.8801'},
#    {'price': '1.14300',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.1308'},
#    {'price': '1.14350',
#     'longCountPercent': '0.0030',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.14400',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0505'},
#    {'price': '1.14450',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.14500',
#     'longCountPercent': '0.0684',
#     'shortCountPercent': '0.0803'},
#    {'price': '1.14550',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.0446'},
#    {'price': '1.14600',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.14650',
#     'longCountPercent': '0.0654',
#     'shortCountPercent': '0.0624'},
#    {'price': '1.14700',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.2200'},
#    {'price': '1.14750',
#     'longCountPercent': '0.0446',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.14800',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0595'},
#    {'price': '1.14850',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0327'},
#    {'price': '1.14900',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.1338'},
#    {'price': '1.14950',
#     'longCountPercent': '1.1923',
#     'shortCountPercent': '0.1100'},
#    {'price': '1.15000',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0268'},
#    {'price': '1.15050',
#     'longCountPercent': '0.0238',
#     'shortCountPercent': '0.0238'},
#    {'price': '1.15100',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.15150',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0892'},
#    {'price': '1.15200',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0327'},
#    {'price': '1.15250',
#     'longCountPercent': '0.0178',
#     'shortCountPercent': '0.0178'},
#    {'price': '1.15300',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.15350',
#     'longCountPercent': '0.0565',
#     'shortCountPercent': '0.0238'},
#    {'price': '1.15400',
#     'longCountPercent': '0.0981',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.15450',
#     'longCountPercent': '0.0833',
#     'shortCountPercent': '0.0327'},
#    {'price': '1.15500',
#     'longCountPercent': '0.0862',
#     'shortCountPercent': '0.0446'},
#    {'price': '1.15550',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.0357'},
#    {'price': '1.15600',
#     'longCountPercent': '0.0624',
#     'shortCountPercent': '0.0238'},
#    {'price': '1.15650',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.15700',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.0476'},
#    {'price': '1.15750',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.0892'},
#    {'price': '1.15800',
#     'longCountPercent': '0.0327',
#     'shortCountPercent': '0.0238'},
#    {'price': '1.15850',
#     'longCountPercent': '0.0357',
#     'shortCountPercent': '0.0654'},
#    {'price': '1.15900',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0535'},
#    {'price': '1.15950',
#     'longCountPercent': '0.1487',
#     'shortCountPercent': '0.0803'},
#    {'price': '1.16000',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0416'},
#    {'price': '1.16050',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0208'},
#    {'price': '1.16100',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0387'},
#    {'price': '1.16150',
#     'longCountPercent': '0.0149',
#     'shortCountPercent': '0.0208'},
#    {'price': '1.16200',
#     'longCountPercent': '0.0476',
#     'shortCountPercent': '0.0505'},
#    {'price': '1.16250',
#     'longCountPercent': '0.0595',
#     'shortCountPercent': '0.0268'},
#    {'price': '1.16300',
#     'longCountPercent': '0.0387',
#     'shortCountPercent': '0.0149'},
#    {'price': '1.16350',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.1130'},
#    {'price': '1.16400',
#     'longCountPercent': '0.0208',
#     'shortCountPercent': '0.0178'},
#    {'price': '1.16450',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.3300'},
#    {'price': '1.16500',
#     'longCountPercent': '0.0119',
#     'shortCountPercent': '0.0446'},
#    {'price': '1.16550',
#     'longCountPercent': '0.0416',
#     'shortCountPercent': '0.0387'},
#    {'price': '1.16600',
#     'longCountPercent': '0.0089',
#     'shortCountPercent': '0.0297'},
#    ...]}}

# %% [markdown]
# ### InstrumentsPositionBook
# Get positionbook data for a specified Instrument.
#
# [Python-Oanda API - InstrumentsPositionBook](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/instruments/instrumentpositionbook.html)

# %%
r = api.request(InstrumentsPositionBook(instrument="EUR_USD"))
r
# Out:
# {'positionBook': {'instrument': 'EUR_USD',
#   'time': '2020-02-22T12:20:00Z',
#   'unixTime': '1582374000',
#   'price': '1.08474',
#   'bucketWidth': '0.00050',
#   'buckets': [{'price': '1.03500',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.03600',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.03650',
#     'longCountPercent': '0.0019',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.03700',
#     'longCountPercent': '0.0019',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.03750',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.03800',
#     'longCountPercent': '0.0056',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.03850',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.03900',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.03950',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.04000',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.04050',
#     'longCountPercent': '0.0259',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.04100',
#     'longCountPercent': '0.0222',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.04150',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.04200',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0093'},
#    {'price': '1.04250',
#     'longCountPercent': '0.0130',
#     'shortCountPercent': '0.0093'},
#    {'price': '1.04300',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.04350',
#     'longCountPercent': '0.0315',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.04400',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.04450',
#     'longCountPercent': '0.0259',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.04500',
#     'longCountPercent': '0.0222',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.04550',
#     'longCountPercent': '0.0148',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.04600',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.04650',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0093'},
#    {'price': '1.04700',
#     'longCountPercent': '0.0148',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.04750',
#     'longCountPercent': '0.0148',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.04800',
#     'longCountPercent': '0.0056',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.04850',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0093'},
#    {'price': '1.04900',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.04950',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.05000',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.05050',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.05100',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0167'},
#    {'price': '1.05150',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.05200',
#     'longCountPercent': '0.0204',
#     'shortCountPercent': '0.0167'},
#    {'price': '1.05250',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.05300',
#     'longCountPercent': '0.0408',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.05350',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.05400',
#     'longCountPercent': '0.0371',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.05450',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.05500',
#     'longCountPercent': '0.0556',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.05550',
#     'longCountPercent': '0.0982',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.05600',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.05650',
#     'longCountPercent': '0.0908',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.05700',
#     'longCountPercent': '0.0704',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.05750',
#     'longCountPercent': '0.0982',
#     'shortCountPercent': '0.0649'},
#    {'price': '1.05800',
#     'longCountPercent': '0.1205',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.05850',
#     'longCountPercent': '0.1316',
#     'shortCountPercent': '0.0519'},
#    {'price': '1.05900',
#     'longCountPercent': '0.0945',
#     'shortCountPercent': '0.0723'},
#    {'price': '1.05950',
#     'longCountPercent': '0.1186',
#     'shortCountPercent': '0.0834'},
#    {'price': '1.06000',
#     'longCountPercent': '0.1205',
#     'shortCountPercent': '0.0778'},
#    {'price': '1.06050',
#     'longCountPercent': '0.1149',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.06100',
#     'longCountPercent': '0.1649',
#     'shortCountPercent': '0.0982'},
#    {'price': '1.06150',
#     'longCountPercent': '0.1835',
#     'shortCountPercent': '0.0741'},
#    {'price': '1.06200',
#     'longCountPercent': '0.1353',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.06250',
#     'longCountPercent': '0.1001',
#     'shortCountPercent': '0.0278'},
#    {'price': '1.06300',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.0500'},
#    {'price': '1.06350',
#     'longCountPercent': '0.1038',
#     'shortCountPercent': '0.0463'},
#    {'price': '1.06400',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0463'},
#    {'price': '1.06450',
#     'longCountPercent': '0.0741',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.06500',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.06550',
#     'longCountPercent': '0.0760',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.06600',
#     'longCountPercent': '0.0982',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.06650',
#     'longCountPercent': '0.0964',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.06700',
#     'longCountPercent': '0.0964',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.06750',
#     'longCountPercent': '0.1038',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.06800',
#     'longCountPercent': '0.1019',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.06850',
#     'longCountPercent': '0.0853',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.06900',
#     'longCountPercent': '0.0704',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.06950',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.07000',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.07050',
#     'longCountPercent': '0.0500',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.07100',
#     'longCountPercent': '0.0389',
#     'shortCountPercent': '0.0334'},
#    {'price': '1.07150',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.07200',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.07250',
#     'longCountPercent': '0.0593',
#     'shortCountPercent': '0.0519'},
#    {'price': '1.07300',
#     'longCountPercent': '0.0908',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.07350',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.07400',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.07450',
#     'longCountPercent': '0.0704',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.07500',
#     'longCountPercent': '0.0908',
#     'shortCountPercent': '0.0259'},
#    {'price': '1.07550',
#     'longCountPercent': '0.0834',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.07600',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.07650',
#     'longCountPercent': '0.0519',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.07700',
#     'longCountPercent': '0.0426',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.07750',
#     'longCountPercent': '0.0389',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.07800',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0704'},
#    {'price': '1.07850',
#     'longCountPercent': '0.1520',
#     'shortCountPercent': '0.2650'},
#    {'price': '1.07900',
#     'longCountPercent': '0.3910',
#     'shortCountPercent': '0.3799'},
#    {'price': '1.07950',
#     'longCountPercent': '0.3632',
#     'shortCountPercent': '0.2595'},
#    {'price': '1.08000',
#     'longCountPercent': '0.3188',
#     'shortCountPercent': '0.1927'},
#    {'price': '1.08050',
#     'longCountPercent': '0.2280',
#     'shortCountPercent': '0.1131'},
#    {'price': '1.08100',
#     'longCountPercent': '0.2187',
#     'shortCountPercent': '0.0964'},
#    {'price': '1.08150',
#     'longCountPercent': '0.1686',
#     'shortCountPercent': '0.0871'},
#    {'price': '1.08200',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.08250',
#     'longCountPercent': '0.1056',
#     'shortCountPercent': '0.0760'},
#    {'price': '1.08300',
#     'longCountPercent': '0.2446',
#     'shortCountPercent': '0.2187'},
#    {'price': '1.08350',
#     'longCountPercent': '0.3558',
#     'shortCountPercent': '0.2613'},
#    {'price': '1.08400',
#     'longCountPercent': '0.2687',
#     'shortCountPercent': '0.1594'},
#    {'price': '1.08450',
#     'longCountPercent': '0.2539',
#     'shortCountPercent': '0.2261'},
#    {'price': '1.08500',
#     'longCountPercent': '0.2650',
#     'shortCountPercent': '0.2057'},
#    {'price': '1.08550',
#     'longCountPercent': '0.4022',
#     'shortCountPercent': '0.2057'},
#    {'price': '1.08600',
#     'longCountPercent': '0.2205',
#     'shortCountPercent': '0.0945'},
#    {'price': '1.08650',
#     'longCountPercent': '0.1446',
#     'shortCountPercent': '0.0871'},
#    {'price': '1.08700',
#     'longCountPercent': '0.2076',
#     'shortCountPercent': '0.0815'},
#    {'price': '1.08750',
#     'longCountPercent': '0.1798',
#     'shortCountPercent': '0.0575'},
#    {'price': '1.08800',
#     'longCountPercent': '0.1427',
#     'shortCountPercent': '0.0575'},
#    {'price': '1.08850',
#     'longCountPercent': '0.1427',
#     'shortCountPercent': '0.0797'},
#    {'price': '1.08900',
#     'longCountPercent': '0.1612',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.08950',
#     'longCountPercent': '0.1260',
#     'shortCountPercent': '0.0500'},
#    {'price': '1.09000',
#     'longCountPercent': '0.1427',
#     'shortCountPercent': '0.0686'},
#    {'price': '1.09050',
#     'longCountPercent': '0.1538',
#     'shortCountPercent': '0.1149'},
#    {'price': '1.09100',
#     'longCountPercent': '0.2261',
#     'shortCountPercent': '0.1483'},
#    {'price': '1.09150',
#     'longCountPercent': '0.2743',
#     'shortCountPercent': '0.1223'},
#    {'price': '1.09200',
#     'longCountPercent': '0.2224',
#     'shortCountPercent': '0.0741'},
#    {'price': '1.09250',
#     'longCountPercent': '0.1075',
#     'shortCountPercent': '0.0797'},
#    {'price': '1.09300',
#     'longCountPercent': '0.1816',
#     'shortCountPercent': '0.0871'},
#    {'price': '1.09350',
#     'longCountPercent': '0.1501',
#     'shortCountPercent': '0.0815'},
#    {'price': '1.09400',
#     'longCountPercent': '0.1631',
#     'shortCountPercent': '0.1112'},
#    {'price': '1.09450',
#     'longCountPercent': '0.2168',
#     'shortCountPercent': '0.0964'},
#    {'price': '1.09500',
#     'longCountPercent': '0.2168',
#     'shortCountPercent': '0.1446'},
#    {'price': '1.09550',
#     'longCountPercent': '0.1260',
#     'shortCountPercent': '0.1001'},
#    {'price': '1.09600',
#     'longCountPercent': '0.1520',
#     'shortCountPercent': '0.0686'},
#    {'price': '1.09650',
#     'longCountPercent': '0.1409',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.09700',
#     'longCountPercent': '0.2076',
#     'shortCountPercent': '0.1297'},
#    {'price': '1.09750',
#     'longCountPercent': '0.2205',
#     'shortCountPercent': '0.1742'},
#    {'price': '1.09800',
#     'longCountPercent': '0.2780',
#     'shortCountPercent': '0.1260'},
#    {'price': '1.09850',
#     'longCountPercent': '0.2409',
#     'shortCountPercent': '0.1297'},
#    {'price': '1.09900',
#     'longCountPercent': '0.2242',
#     'shortCountPercent': '0.1353'},
#    {'price': '1.09950',
#     'longCountPercent': '0.2224',
#     'shortCountPercent': '0.1909'},
#    {'price': '1.10000',
#     'longCountPercent': '0.3707',
#     'shortCountPercent': '0.1816'},
#    {'price': '1.10050',
#     'longCountPercent': '0.3392',
#     'shortCountPercent': '0.2280'},
#    {'price': '1.10100',
#     'longCountPercent': '0.4003',
#     'shortCountPercent': '0.2836'},
#    {'price': '1.10150',
#     'longCountPercent': '0.4392',
#     'shortCountPercent': '0.3039'},
#    {'price': '1.10200',
#     'longCountPercent': '0.4800',
#     'shortCountPercent': '0.3317'},
#    {'price': '1.10250',
#     'longCountPercent': '0.4670',
#     'shortCountPercent': '0.2632'},
#    {'price': '1.10300',
#     'longCountPercent': '0.4022',
#     'shortCountPercent': '0.2150'},
#    {'price': '1.10350',
#     'longCountPercent': '0.2910',
#     'shortCountPercent': '0.1761'},
#    {'price': '1.10400',
#     'longCountPercent': '0.2873',
#     'shortCountPercent': '0.1872'},
#    {'price': '1.10450',
#     'longCountPercent': '0.2947',
#     'shortCountPercent': '0.1927'},
#    {'price': '1.10500',
#     'longCountPercent': '0.2965',
#     'shortCountPercent': '0.2409'},
#    {'price': '1.10550',
#     'longCountPercent': '0.3095',
#     'shortCountPercent': '0.2224'},
#    {'price': '1.10600',
#     'longCountPercent': '0.3521',
#     'shortCountPercent': '0.1575'},
#    {'price': '1.10650',
#     'longCountPercent': '0.3466',
#     'shortCountPercent': '0.1946'},
#    {'price': '1.10700',
#     'longCountPercent': '0.3985',
#     'shortCountPercent': '0.3132'},
#    {'price': '1.10750',
#     'longCountPercent': '0.5097',
#     'shortCountPercent': '0.3651'},
#    {'price': '1.10800',
#     'longCountPercent': '0.5838',
#     'shortCountPercent': '0.3651'},
#    {'price': '1.10850',
#     'longCountPercent': '0.4355',
#     'shortCountPercent': '0.3243'},
#    {'price': '1.10900',
#     'longCountPercent': '0.6264',
#     'shortCountPercent': '0.3725'},
#    {'price': '1.10950',
#     'longCountPercent': '0.5578',
#     'shortCountPercent': '0.2150'},
#    {'price': '1.11000',
#     'longCountPercent': '0.2984',
#     'shortCountPercent': '0.2576'},
#    {'price': '1.11050',
#     'longCountPercent': '0.3132',
#     'shortCountPercent': '0.2113'},
#    {'price': '1.11100',
#     'longCountPercent': '0.2928',
#     'shortCountPercent': '0.1890'},
#    {'price': '1.11150',
#     'longCountPercent': '0.3114',
#     'shortCountPercent': '0.2354'},
#    {'price': '1.11200',
#     'longCountPercent': '0.3354',
#     'shortCountPercent': '0.2261'},
#    {'price': '1.11250',
#     'longCountPercent': '0.4781',
#     'shortCountPercent': '0.3206'},
#    {'price': '1.11300',
#     'longCountPercent': '0.4077',
#     'shortCountPercent': '0.2317'},
#    {'price': '1.11350',
#     'longCountPercent': '0.5245',
#     'shortCountPercent': '0.2984'},
#    {'price': '1.11400',
#     'longCountPercent': '0.4151',
#     'shortCountPercent': '0.2409'},
#    {'price': '1.11450',
#     'longCountPercent': '0.5004',
#     'shortCountPercent': '0.2891'},
#    {'price': '1.11500',
#     'longCountPercent': '0.5208',
#     'shortCountPercent': '0.2595'},
#    {'price': '1.11550',
#     'longCountPercent': '0.3929',
#     'shortCountPercent': '0.2242'},
#    {'price': '1.11600',
#     'longCountPercent': '0.3836',
#     'shortCountPercent': '0.2595'},
#    {'price': '1.11650',
#     'longCountPercent': '0.4096',
#     'shortCountPercent': '0.2928'},
#    {'price': '1.11700',
#     'longCountPercent': '0.2965',
#     'shortCountPercent': '0.2483'},
#    {'price': '1.11750',
#     'longCountPercent': '0.3151',
#     'shortCountPercent': '0.1798'},
#    {'price': '1.11800',
#     'longCountPercent': '0.3076',
#     'shortCountPercent': '0.1946'},
#    {'price': '1.11850',
#     'longCountPercent': '0.3076',
#     'shortCountPercent': '0.2372'},
#    {'price': '1.11900',
#     'longCountPercent': '0.3818',
#     'shortCountPercent': '0.2669'},
#    {'price': '1.11950',
#     'longCountPercent': '0.4355',
#     'shortCountPercent': '0.2891'},
#    {'price': '1.12000',
#     'longCountPercent': '0.4114',
#     'shortCountPercent': '0.3021'},
#    {'price': '1.12050',
#     'longCountPercent': '0.4522',
#     'shortCountPercent': '0.3670'},
#    {'price': '1.12100',
#     'longCountPercent': '0.5337',
#     'shortCountPercent': '0.3132'},
#    {'price': '1.12150',
#     'longCountPercent': '0.5337',
#     'shortCountPercent': '0.3039'},
#    {'price': '1.12200',
#     'longCountPercent': '0.4188',
#     'shortCountPercent': '0.2409'},
#    {'price': '1.12250',
#     'longCountPercent': '0.4374',
#     'shortCountPercent': '0.2391'},
#    {'price': '1.12300',
#     'longCountPercent': '0.3670',
#     'shortCountPercent': '0.2224'},
#    {'price': '1.12350',
#     'longCountPercent': '0.3540',
#     'shortCountPercent': '0.1983'},
#    {'price': '1.12400',
#     'longCountPercent': '0.3392',
#     'shortCountPercent': '0.1705'},
#    {'price': '1.12450',
#     'longCountPercent': '0.2817',
#     'shortCountPercent': '0.1334'},
#    {'price': '1.12500',
#     'longCountPercent': '0.2317',
#     'shortCountPercent': '0.1390'},
#    {'price': '1.12550',
#     'longCountPercent': '0.3317',
#     'shortCountPercent': '0.1890'},
#    {'price': '1.12600',
#     'longCountPercent': '0.3002',
#     'shortCountPercent': '0.1705'},
#    {'price': '1.12650',
#     'longCountPercent': '0.2520',
#     'shortCountPercent': '0.1334'},
#    {'price': '1.12700',
#     'longCountPercent': '0.2595',
#     'shortCountPercent': '0.1816'},
#    {'price': '1.12750',
#     'longCountPercent': '0.3262',
#     'shortCountPercent': '0.2002'},
#    {'price': '1.12800',
#     'longCountPercent': '0.2446',
#     'shortCountPercent': '0.1501'},
#    {'price': '1.12850',
#     'longCountPercent': '0.2984',
#     'shortCountPercent': '0.1742'},
#    {'price': '1.12900',
#     'longCountPercent': '0.2298',
#     'shortCountPercent': '0.1983'},
#    {'price': '1.12950',
#     'longCountPercent': '0.3262',
#     'shortCountPercent': '0.1724'},
#    {'price': '1.13000',
#     'longCountPercent': '0.2576',
#     'shortCountPercent': '0.1724'},
#    {'price': '1.13050',
#     'longCountPercent': '0.2428',
#     'shortCountPercent': '0.1909'},
#    {'price': '1.13100',
#     'longCountPercent': '0.2539',
#     'shortCountPercent': '0.1705'},
#    {'price': '1.13150',
#     'longCountPercent': '0.2687',
#     'shortCountPercent': '0.1835'},
#    {'price': '1.13200',
#     'longCountPercent': '0.2224',
#     'shortCountPercent': '0.1686'},
#    {'price': '1.13250',
#     'longCountPercent': '0.2650',
#     'shortCountPercent': '0.1816'},
#    {'price': '1.13300',
#     'longCountPercent': '0.2706',
#     'shortCountPercent': '0.2057'},
#    {'price': '1.13350',
#     'longCountPercent': '0.2947',
#     'shortCountPercent': '0.2150'},
#    {'price': '1.13400',
#     'longCountPercent': '0.3151',
#     'shortCountPercent': '0.2150'},
#    {'price': '1.13450',
#     'longCountPercent': '0.2595',
#     'shortCountPercent': '0.1686'},
#    {'price': '1.13500',
#     'longCountPercent': '0.2613',
#     'shortCountPercent': '0.1686'},
#    {'price': '1.13550',
#     'longCountPercent': '0.2595',
#     'shortCountPercent': '0.1890'},
#    {'price': '1.13600',
#     'longCountPercent': '0.2947',
#     'shortCountPercent': '0.2298'},
#    {'price': '1.13650',
#     'longCountPercent': '0.4133',
#     'shortCountPercent': '0.2576'},
#    {'price': '1.13700',
#     'longCountPercent': '0.3632',
#     'shortCountPercent': '0.2242'},
#    {'price': '1.13750',
#     'longCountPercent': '0.3058',
#     'shortCountPercent': '0.2317'},
#    {'price': '1.13800',
#     'longCountPercent': '0.2502',
#     'shortCountPercent': '0.1983'},
#    {'price': '1.13850',
#     'longCountPercent': '0.3021',
#     'shortCountPercent': '0.2409'},
#    {'price': '1.13900',
#     'longCountPercent': '0.3039',
#     'shortCountPercent': '0.2261'},
#    {'price': '1.13950',
#     'longCountPercent': '0.3410',
#     'shortCountPercent': '0.1964'},
#    {'price': '1.14000',
#     'longCountPercent': '0.2520',
#     'shortCountPercent': '0.1890'},
#    {'price': '1.14050',
#     'longCountPercent': '0.2687',
#     'shortCountPercent': '0.1798'},
#    {'price': '1.14100',
#     'longCountPercent': '0.2706',
#     'shortCountPercent': '0.1872'},
#    {'price': '1.14150',
#     'longCountPercent': '0.1909',
#     'shortCountPercent': '0.1093'},
#    {'price': '1.14200',
#     'longCountPercent': '0.1890',
#     'shortCountPercent': '0.1038'},
#    {'price': '1.14250',
#     'longCountPercent': '0.1575',
#     'shortCountPercent': '0.1149'},
#    {'price': '1.14300',
#     'longCountPercent': '0.1668',
#     'shortCountPercent': '0.0927'},
#    {'price': '1.14350',
#     'longCountPercent': '0.1594',
#     'shortCountPercent': '0.1149'},
#    {'price': '1.14400',
#     'longCountPercent': '0.1483',
#     'shortCountPercent': '0.0908'},
#    {'price': '1.14450',
#     'longCountPercent': '0.1205',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.14500',
#     'longCountPercent': '0.0945',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.14550',
#     'longCountPercent': '0.1242',
#     'shortCountPercent': '0.0853'},
#    {'price': '1.14600',
#     'longCountPercent': '0.1334',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.14650',
#     'longCountPercent': '0.1538',
#     'shortCountPercent': '0.0964'},
#    {'price': '1.14700',
#     'longCountPercent': '0.1538',
#     'shortCountPercent': '0.0815'},
#    {'price': '1.14750',
#     'longCountPercent': '0.0890',
#     'shortCountPercent': '0.0908'},
#    {'price': '1.14800',
#     'longCountPercent': '0.0834',
#     'shortCountPercent': '0.0519'},
#    {'price': '1.14850',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0556'},
#    {'price': '1.14900',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0334'},
#    {'price': '1.14950',
#     'longCountPercent': '0.0815',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.15000',
#     'longCountPercent': '0.0519',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.15050',
#     'longCountPercent': '0.0500',
#     'shortCountPercent': '0.0463'},
#    {'price': '1.15100',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0686'},
#    {'price': '1.15150',
#     'longCountPercent': '0.0834',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.15200',
#     'longCountPercent': '0.0741',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.15250',
#     'longCountPercent': '0.1019',
#     'shortCountPercent': '0.0463'},
#    {'price': '1.15300',
#     'longCountPercent': '0.0778',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.15350',
#     'longCountPercent': '0.0537',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.15400',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.15450',
#     'longCountPercent': '0.0760',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.15500',
#     'longCountPercent': '0.1038',
#     'shortCountPercent': '0.0760'},
#    {'price': '1.15550',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.0927'},
#    {'price': '1.15600',
#     'longCountPercent': '0.1464',
#     'shortCountPercent': '0.0778'},
#    {'price': '1.15650',
#     'longCountPercent': '0.0834',
#     'shortCountPercent': '0.0575'},
#    {'price': '1.15700',
#     'longCountPercent': '0.1316',
#     'shortCountPercent': '0.0982'},
#    {'price': '1.15750',
#     'longCountPercent': '0.1446',
#     'shortCountPercent': '0.0723'},
#    {'price': '1.15800',
#     'longCountPercent': '0.1093',
#     'shortCountPercent': '0.0945'},
#    {'price': '1.15850',
#     'longCountPercent': '0.1390',
#     'shortCountPercent': '0.0853'},
#    {'price': '1.15900',
#     'longCountPercent': '0.1464',
#     'shortCountPercent': '0.1260'},
#    {'price': '1.15950',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.1001'},
#    {'price': '1.16000',
#     'longCountPercent': '0.1390',
#     'shortCountPercent': '0.0871'},
#    {'price': '1.16050',
#     'longCountPercent': '0.1390',
#     'shortCountPercent': '0.0686'},
#    {'price': '1.16100',
#     'longCountPercent': '0.1371',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.16150',
#     'longCountPercent': '0.1075',
#     'shortCountPercent': '0.0871'},
#    {'price': '1.16200',
#     'longCountPercent': '0.1260',
#     'shortCountPercent': '0.1075'},
#    {'price': '1.16250',
#     'longCountPercent': '0.1149',
#     'shortCountPercent': '0.1075'},
#    {'price': '1.16300',
#     'longCountPercent': '0.1427',
#     'shortCountPercent': '0.1168'},
#    {'price': '1.16350',
#     'longCountPercent': '0.1316',
#     'shortCountPercent': '0.1001'},
#    {'price': '1.16400',
#     'longCountPercent': '0.1038',
#     'shortCountPercent': '0.1223'},
#    {'price': '1.16450',
#     'longCountPercent': '0.1575',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.16500',
#     'longCountPercent': '0.1557',
#     'shortCountPercent': '0.1464'},
#    {'price': '1.16550',
#     'longCountPercent': '0.1872',
#     'shortCountPercent': '0.1538'},
#    {'price': '1.16600',
#     'longCountPercent': '0.1816',
#     'shortCountPercent': '0.1093'},
#    {'price': '1.16650',
#     'longCountPercent': '0.1742',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.16700',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.1205'},
#    {'price': '1.16750',
#     'longCountPercent': '0.1297',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.16800',
#     'longCountPercent': '0.1297',
#     'shortCountPercent': '0.0815'},
#    {'price': '1.16850',
#     'longCountPercent': '0.1446',
#     'shortCountPercent': '0.1019'},
#    {'price': '1.16900',
#     'longCountPercent': '0.1761',
#     'shortCountPercent': '0.0945'},
#    {'price': '1.16950',
#     'longCountPercent': '0.1520',
#     'shortCountPercent': '0.0834'},
#    {'price': '1.17000',
#     'longCountPercent': '0.1371',
#     'shortCountPercent': '0.1056'},
#    {'price': '1.17050',
#     'longCountPercent': '0.1483',
#     'shortCountPercent': '0.0945'},
#    {'price': '1.17100',
#     'longCountPercent': '0.1205',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.17150',
#     'longCountPercent': '0.1001',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.17200',
#     'longCountPercent': '0.0853',
#     'shortCountPercent': '0.0612'},
#    {'price': '1.17250',
#     'longCountPercent': '0.0964',
#     'shortCountPercent': '0.1001'},
#    {'price': '1.17300',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.1056'},
#    {'price': '1.17350',
#     'longCountPercent': '0.1853',
#     'shortCountPercent': '0.1242'},
#    {'price': '1.17400',
#     'longCountPercent': '0.1594',
#     'shortCountPercent': '0.1390'},
#    {'price': '1.17450',
#     'longCountPercent': '0.2039',
#     'shortCountPercent': '0.1501'},
#    {'price': '1.17500',
#     'longCountPercent': '0.1872',
#     'shortCountPercent': '0.0927'},
#    {'price': '1.17550',
#     'longCountPercent': '0.1279',
#     'shortCountPercent': '0.1334'},
#    {'price': '1.17600',
#     'longCountPercent': '0.1946',
#     'shortCountPercent': '0.1038'},
#    {'price': '1.17650',
#     'longCountPercent': '0.2094',
#     'shortCountPercent': '0.1371'},
#    {'price': '1.17700',
#     'longCountPercent': '0.1909',
#     'shortCountPercent': '0.1001'},
#    {'price': '1.17750',
#     'longCountPercent': '0.2168',
#     'shortCountPercent': '0.1112'},
#    {'price': '1.17800',
#     'longCountPercent': '0.1853',
#     'shortCountPercent': '0.1371'},
#    {'price': '1.17850',
#     'longCountPercent': '0.1742',
#     'shortCountPercent': '0.0853'},
#    {'price': '1.17900',
#     'longCountPercent': '0.1575',
#     'shortCountPercent': '0.1316'},
#    {'price': '1.17950',
#     'longCountPercent': '0.1872',
#     'shortCountPercent': '0.0834'},
#    {'price': '1.18000',
#     'longCountPercent': '0.1557',
#     'shortCountPercent': '0.0834'},
#    {'price': '1.18050',
#     'longCountPercent': '0.1316',
#     'shortCountPercent': '0.0982'},
#    {'price': '1.18100',
#     'longCountPercent': '0.1297',
#     'shortCountPercent': '0.0704'},
#    {'price': '1.18150',
#     'longCountPercent': '0.1334',
#     'shortCountPercent': '0.0556'},
#    {'price': '1.18200',
#     'longCountPercent': '0.1001',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.18250',
#     'longCountPercent': '0.1056',
#     'shortCountPercent': '0.0760'},
#    {'price': '1.18300',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.18350',
#     'longCountPercent': '0.0723',
#     'shortCountPercent': '0.0630'},
#    {'price': '1.18400',
#     'longCountPercent': '0.0834',
#     'shortCountPercent': '0.0649'},
#    {'price': '1.18450',
#     'longCountPercent': '0.1112',
#     'shortCountPercent': '0.1056'},
#    {'price': '1.18500',
#     'longCountPercent': '0.1001',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.18550',
#     'longCountPercent': '0.0723',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.18600',
#     'longCountPercent': '0.0815',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.18650',
#     'longCountPercent': '0.1112',
#     'shortCountPercent': '0.0667'},
#    {'price': '1.18700',
#     'longCountPercent': '0.0982',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.18750',
#     'longCountPercent': '0.0797',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.18800',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.18850',
#     'longCountPercent': '0.0575',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.18900',
#     'longCountPercent': '0.0334',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.18950',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0575'},
#    {'price': '1.19000',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0463'},
#    {'price': '1.19050',
#     'longCountPercent': '0.0556',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.19100',
#     'longCountPercent': '0.0760',
#     'shortCountPercent': '0.0612'},
#    {'price': '1.19150',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.19200',
#     'longCountPercent': '0.0797',
#     'shortCountPercent': '0.0556'},
#    {'price': '1.19250',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.19300',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0649'},
#    {'price': '1.19350',
#     'longCountPercent': '0.0741',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.19400',
#     'longCountPercent': '0.0593',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.19450',
#     'longCountPercent': '0.0593',
#     'shortCountPercent': '0.0334'},
#    {'price': '1.19500',
#     'longCountPercent': '0.0797',
#     'shortCountPercent': '0.0760'},
#    {'price': '1.19550',
#     'longCountPercent': '0.0723',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.19600',
#     'longCountPercent': '0.0704',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.19650',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.19700',
#     'longCountPercent': '0.0612',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.19750',
#     'longCountPercent': '0.0519',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.19800',
#     'longCountPercent': '0.0500',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.19850',
#     'longCountPercent': '0.0556',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.19900',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.19950',
#     'longCountPercent': '0.0371',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.20000',
#     'longCountPercent': '0.0445',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.20050',
#     'longCountPercent': '0.0463',
#     'shortCountPercent': '0.0278'},
#    {'price': '1.20100',
#     'longCountPercent': '0.0334',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.20150',
#     'longCountPercent': '0.0426',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.20200',
#     'longCountPercent': '0.0259',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.20250',
#     'longCountPercent': '0.0371',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.20300',
#     'longCountPercent': '0.0408',
#     'shortCountPercent': '0.0167'},
#    {'price': '1.20350',
#     'longCountPercent': '0.0352',
#     'shortCountPercent': '0.0259'},
#    {'price': '1.20400',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.20450',
#     'longCountPercent': '0.0408',
#     'shortCountPercent': '0.0259'},
#    {'price': '1.20500',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.20550',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.20600',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.20650',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.20700',
#     'longCountPercent': '0.0463',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.20750',
#     'longCountPercent': '0.0389',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.20800',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.20850',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.20900',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.20950',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.21000',
#     'longCountPercent': '0.0130',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.21050',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.21100',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.21150',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.21200',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.21250',
#     'longCountPercent': '0.0334',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.21300',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.21350',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.21400',
#     'longCountPercent': '0.0056',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.21450',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.21500',
#     'longCountPercent': '0.0093',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.21550',
#     'longCountPercent': '0.0019',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.21600',
#     'longCountPercent': '0.0056',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.21650',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.21700',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.21750',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.21800',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.21850',
#     'longCountPercent': '0.0148',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.21900',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.21950',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0167'},
#    {'price': '1.22000',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.22050',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.22100',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0408'},
#    {'price': '1.22150',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0259'},
#    {'price': '1.22200',
#     'longCountPercent': '0.0408',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.22250',
#     'longCountPercent': '0.0352',
#     'shortCountPercent': '0.0556'},
#    {'price': '1.22300',
#     'longCountPercent': '0.0519',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.22350',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.22400',
#     'longCountPercent': '0.0593',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.22450',
#     'longCountPercent': '0.0389',
#     'shortCountPercent': '0.0297'},
#    {'price': '1.22500',
#     'longCountPercent': '0.0408',
#     'shortCountPercent': '0.0259'},
#    {'price': '1.22550',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0500'},
#    {'price': '1.22600',
#     'longCountPercent': '0.0723',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.22650',
#     'longCountPercent': '0.0778',
#     'shortCountPercent': '0.0723'},
#    {'price': '1.22700',
#     'longCountPercent': '0.0908',
#     'shortCountPercent': '0.0556'},
#    {'price': '1.22750',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0519'},
#    {'price': '1.22800',
#     'longCountPercent': '0.0871',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.22850',
#     'longCountPercent': '0.0797',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.22900',
#     'longCountPercent': '0.0649',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.22950',
#     'longCountPercent': '0.0853',
#     'shortCountPercent': '0.0389'},
#    {'price': '1.23000',
#     'longCountPercent': '0.0593',
#     'shortCountPercent': '0.0593'},
#    {'price': '1.23050',
#     'longCountPercent': '0.1056',
#     'shortCountPercent': '0.0741'},
#    {'price': '1.23100',
#     'longCountPercent': '0.0853',
#     'shortCountPercent': '0.0982'},
#    {'price': '1.23150',
#     'longCountPercent': '0.1131',
#     'shortCountPercent': '0.0723'},
#    {'price': '1.23200',
#     'longCountPercent': '0.1056',
#     'shortCountPercent': '0.0704'},
#    {'price': '1.23250',
#     'longCountPercent': '0.1019',
#     'shortCountPercent': '0.0723'},
#    {'price': '1.23300',
#     'longCountPercent': '0.0964',
#     'shortCountPercent': '0.0760'},
#    {'price': '1.23350',
#     'longCountPercent': '0.1334',
#     'shortCountPercent': '0.0612'},
#    {'price': '1.23400',
#     'longCountPercent': '0.1075',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.23450',
#     'longCountPercent': '0.0815',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.23500',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0352'},
#    {'price': '1.23550',
#     'longCountPercent': '0.0575',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.23600',
#     'longCountPercent': '0.0556',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.23650',
#     'longCountPercent': '0.0741',
#     'shortCountPercent': '0.0500'},
#    {'price': '1.23700',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0500'},
#    {'price': '1.23750',
#     'longCountPercent': '0.0853',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.23800',
#     'longCountPercent': '0.0815',
#     'shortCountPercent': '0.0426'},
#    {'price': '1.23850',
#     'longCountPercent': '0.0630',
#     'shortCountPercent': '0.0278'},
#    {'price': '1.23900',
#     'longCountPercent': '0.0723',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.23950',
#     'longCountPercent': '0.0334',
#     'shortCountPercent': '0.0315'},
#    {'price': '1.24000',
#     'longCountPercent': '0.0667',
#     'shortCountPercent': '0.0537'},
#    {'price': '1.24050',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0482'},
#    {'price': '1.24100',
#     'longCountPercent': '0.0686',
#     'shortCountPercent': '0.0445'},
#    {'price': '1.24150',
#     'longCountPercent': '0.0482',
#     'shortCountPercent': '0.0371'},
#    {'price': '1.24200',
#     'longCountPercent': '0.0426',
#     'shortCountPercent': '0.0241'},
#    {'price': '1.24250',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.24300',
#     'longCountPercent': '0.0297',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.24350',
#     'longCountPercent': '0.0222',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.24400',
#     'longCountPercent': '0.0278',
#     'shortCountPercent': '0.0111'},
#    {'price': '1.24450',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0222'},
#    {'price': '1.24500',
#     'longCountPercent': '0.0519',
#     'shortCountPercent': '0.0222'},
#    {'price': '1.24550',
#     'longCountPercent': '0.0352',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.24600',
#     'longCountPercent': '0.0130',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.24650',
#     'longCountPercent': '0.0222',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.24700',
#     'longCountPercent': '0.0056',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.24750',
#     'longCountPercent': '0.0167',
#     'shortCountPercent': '0.0130'},
#    {'price': '1.24800',
#     'longCountPercent': '0.0204',
#     'shortCountPercent': '0.0185'},
#    {'price': '1.24850',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.24900',
#     'longCountPercent': '0.0148',
#     'shortCountPercent': '0.0074'},
#    {'price': '1.24950',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0148'},
#    {'price': '1.25000',
#     'longCountPercent': '0.0241',
#     'shortCountPercent': '0.0204'},
#    {'price': '1.25050',
#     'longCountPercent': '0.0130',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.25100',
#     'longCountPercent': '0.0185',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.25150',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.25200',
#     'longCountPercent': '0.0000',
#     'shortCountPercent': '0.0056'},
#    {'price': '1.25250',
#     'longCountPercent': '0.0019',
#     'shortCountPercent': '0.0037'},
#    {'price': '1.25300',
#     'longCountPercent': '0.0037',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.25350',
#     'longCountPercent': '0.0019',
#     'shortCountPercent': '0.0019'},
#    {'price': '1.25400',
#     'longCountPercent': '0.0111',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.25450',
#     'longCountPercent': '0.0074',
#     'shortCountPercent': '0.0000'},
#    {'price': '1.25500',
#     'longCountPercent': '0.0037',
#     'shortCountPercent': '0.0000'}]}}

# %% [markdown]
# ## Pricing Info
# [Oanda-API - Pricing](http://developer.oanda.com/rest-live-v20/pricing-ep/)
#
# [Python-Oanda API-Pricing](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/pricing.html)
#
# - PricingInfo
# - PricingStream

# %%
from oandapyV20.endpoints.pricing import PricingInfo, PricingStream

# %% [markdown]
# ### Pricing Info
# Get pricing information for a specified list of Instruments within an account.
#
# [Python-Oanda API-Pricing Info](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/pricing/pricinginfo.html)

# %%
params = {'instruments':"EUR_USD"}
r = api.request(PricingInfo(accountID, params))
r
# Out:
# {'time': '2020-02-22T12:23:27.510323719Z',
#  'prices': [{'type': 'PRICE',
#    'time': '2020-02-21T21:59:53.269369279Z',
#    'bids': [{'price': '1.08458', 'liquidity': 10000000}],
#    'asks': [{'price': '1.08488', 'liquidity': 10000000}],
#    'closeoutBid': '1.08458',
#    'closeoutAsk': '1.08488',
#    'status': 'non-tradeable',
#    'tradeable': False,
#    'unitsAvailable': {'default': {'long': '4609442', 'short': '4609440'},
#     'openOnly': {'long': '0', 'short': '4609440'},
#     'reduceFirst': {'long': '4609442', 'short': '4609440'},
#     'reduceOnly': {'long': '1', 'short': '0'}},
#    'quoteHomeConversionFactors': {'positiveUnits': '1.00000000',
#     'negativeUnits': '1.00000000'},
#    'instrument': 'EUR_USD'}]}

# %% [markdown]
# ### Pricing Stream
# Get realtime pricing information for a specified list of Instruments.
#
# [Python-Oanda API-Pricing Stream](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/pricing/pricingstream.html)

# %%
params = {'instruments':"EUR_USD"}
r = api.request(PricingStream(accountID, params))
r
# Out:
# <generator object API.__stream_request at 0x7f27e4ad5990>

# %%
import json

maxrecs = 11
for ticks in r:
    print(json.dumps(ticks))
    maxrecs = maxrecs - 1
    if maxrecs == 0:
        r.close()
# Out:
# {"type": "PRICE", "time": "2020-02-21T21:59:53.269369279Z", "bids": [{"price": "1.08458", "liquidity": 10000000}], "asks": [{"price": "1.08488", "liquidity": 10000000}], "closeoutBid": "1.08458", "closeoutAsk": "1.08488", "status": "non-tradeable", "tradeable": false, "instrument": "EUR_USD"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:34.883666597Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:39.885478278Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:44.892583143Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:49.904172690Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:54.908783770Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:23:59.913965458Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:24:04.920646921Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:24:09.923399575Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:24:14.928384898Z"}
# {"type": "HEARTBEAT", "time": "2020-02-22T12:24:19.934317147Z"}

# %% [markdown]
# ## Orders
# [Oanda API-Orders](http://developer.oanda.com/rest-live-v20/order-df/)
#
# [Python-Oanda API-Orders](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders.html)
#
# - OrderList
# - OrderDetails
# - OrdersPending
# - OrderCreate
# - OrderReplace
# - OrderCancel
# - OrderClientExtensions

# %%
from oandapyV20.endpoints.orders \
import OrderList, OrderDetails, OrdersPending, OrderCreate, OrderReplace

# %% [markdown]
# ### Order List
#
# [Python-Oanda API-Order List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders/orderlist.html)

# %%
r = api.request(OrderList(accountID))
r
# Out:
# {'orders': [{'id': '8',
#    'createTime': '2020-02-21T21:53:52.913988823Z',
#    'replacesOrderID': '6',
#    'type': 'TAKE_PROFIT',
#    'tradeID': '5',
#    'price': '0.10000',
#    'timeInForce': 'GTC',
#    'triggerCondition': 'DEFAULT',
#    'state': 'PENDING'}],
#  'lastTransactionID': '9'}

# %%
orderID = r['orders'][0]['id']
orderID
# Out:
# '8'

# %% [markdown]
# ### Order Details
# Get details for a single Order in an Account.
#
# [Python-Oanda API-Order Details](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders/orderdetails.html)

# %%
r = api.request(OrderDetails(accountID, orderID))
r
# Out:
# {'order': {'id': '8',
#   'createTime': '2020-02-21T21:53:52.913988823Z',
#   'replacesOrderID': '6',
#   'type': 'TAKE_PROFIT',
#   'tradeID': '5',
#   'price': '0.10000',
#   'timeInForce': 'GTC',
#   'triggerCondition': 'DEFAULT',
#   'state': 'PENDING'},
#  'lastTransactionID': '9'}

# %% [markdown]
# ### Orders Pending
# List all pending Orders in an Account.
#
# [Oanda-API - Orders Pending](http://developer.oanda.com/rest-live-v20/order-ep/#collapse_endpoint_4)
#
# [Python-Oanda API-Orders Pending](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders/orderspending.html)

# %%
r = api.request(OrdersPending(accountID))
r
# Out:
# {'orders': [{'id': '8',
#    'createTime': '2020-02-21T21:53:52.913988823Z',
#    'replacesOrderID': '6',
#    'type': 'TAKE_PROFIT',
#    'tradeID': '5',
#    'price': '0.10000',
#    'timeInForce': 'GTC',
#    'triggerCondition': 'DEFAULT',
#    'state': 'PENDING'}],
#  'lastTransactionID': '9'}

# %% [markdown]
# ### Order Create
# Create an Order for an Account.
#
# [Python-Oanda API-Order Create](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders/ordercreate.html)

# %% [raw]
# Orderbody example:
#
# {
#   "order": {
#     "price": "1.2",
#     "stopLossOnFill": {
#       "timeInForce": "GTC",
#       "price": "1.22"
#     },
#     "timeInForce": "GTC",
#     "instrument": "EUR_USD",
#     "units": "-100",
#     "type": "LIMIT",
#     "positionFill": "DEFAULT"
#   }
# }
#
# >>> import oandapyV20
# >>> import oandapyV20.endpoints.orders as orders
# >>> client = oandapyV20.API(access_token=...)
# >>> r = orders.OrderCreate(accountID, data=data)
# >>> client.request(r)
# >>> print r.response
#
# {
#   "orderCreateTransaction": {
#     "price": "1.20000",
#     "stopLossOnFill": {
#       "timeInForce": "GTC",
#       "price": "1.22000"
#     },
#     "timeInForce": "GTC",
#     "reason": "CLIENT_ORDER",
#     "id": "2304",
#     "batchID": "2304",
#     "triggerCondition": "TRIGGER_DEFAULT",
#     "positionFill": "DEFAULT",
#     "userID": 1435156,
#     "instrument": "EUR_USD",
#     "time": "2016-10-24T21:48:18.593753865Z",
#     "units": "-100",
#     "type": "LIMIT_ORDER",
#     "accountID": "101-004-1435156-001"
#   },
#   "lastTransactionID": "2304",
#   "relatedTransactionIDs": [
#     "2304"
#   ]
# }

# %% [markdown]
# ### Order Replace
#
# Replace an Order in an Account by simultaneously cancelling it and creating a replacement Order.
#
# [Python-Oanda API - Order Replace]('https://oanda-api-v20.readthedocs.io/en/latest/endpoints/orders/orderreplace.html')

# %% [raw]
# >>> import oandapyV20
# >>> import oandapyV20.endpoints.orders as orders
# >>> client = oandapyV20.API(access_token=...)
# >>> data =
#         {
#           "order": {
#             "units": "-500000",
#             "instrument": "EUR_USD",
#             "price": "1.25000",
#             "type": "LIMIT"
#           }
#         }
#
# >>> r = orders.OrderReplace(accountID=..., orderID=..., data=data)
# >>> client.request(r)
# >>> print r.response
#
# Output:
#
# {
#   "orderCreateTransaction": {
#     "price": "1.25000",
#     "timeInForce": "GTC",
#     "reason": "REPLACEMENT",
#     "clientExtensions": {
#       "comment": "myComment",
#       "id": "myID"
#     },
#     "id": "2307",
#     "batchID": "2306",
#     "triggerCondition": "TRIGGER_DEFAULT",
#     "replacesOrderID": "2304",
#     "positionFill": "DEFAULT",
#     "userID": 1435156,
#     "instrument": "EUR_USD",
#     "time": "2016-10-25T19:45:38.558056359Z",
#     "units": "-500000",
#     "type": "LIMIT_ORDER",
#     "accountID": "101-004-1435156-001"
#   },
#   "orderCancelTransaction": {
#     "orderID": "2304",
#     "clientOrderID": "myID",
#     "reason": "CLIENT_REQUEST_REPLACED",
#     "batchID": "2306",
#     "time": "2016-10-25T19:45:38.558056359Z",
#     "type": "ORDER_CANCEL",
#     "replacedByOrderID": "2307",
#     "userID": 1435156,
#     "id": "2306",
#     "accountID": "101-004-1435156-001"
#   },
#   "lastTransactionID": "2307",
#   "relatedTransactionIDs": [
#     "2306",
#     "2307"
#   ]
# }

# %% [markdown]
# ## Trades
#
# [Python-Oanda API - Trades](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/trades.html)
#
# - OpenTrades
# - TradeCRCDO
# - TradeClientExtensions
# - TradeClose
# - TradeDetails
# - TradesList

# %%
from oandapyV20.endpoints.trades import TradesList, TradeDetails

# %% [markdown]
# ### Trades List
# Get a list of trades for an Account.
#
# [Python-Oanda API-Trades List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/trades/tradeslist.html)

# %%
r = api.request(TradesList(accountID))
r
# Out:
# {'trades': [{'id': '5',
#    'instrument': 'EUR_USD',
#    'price': '1.08477',
#    'openTime': '2020-02-21T21:22:10.236098884Z',
#    'initialUnits': '-1',
#    'initialMarginRequired': '0.0217',
#    'state': 'OPEN',
#    'currentUnits': '-1',
#    'realizedPL': '0.0000',
#    'financing': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'unrealizedPL': '-0.0001',
#    'marginUsed': '0.0217',
#    'takeProfitOrder': {'id': '8',
#     'createTime': '2020-02-21T21:53:52.913988823Z',
#     'replacesOrderID': '6',
#     'type': 'TAKE_PROFIT',
#     'tradeID': '5',
#     'price': '0.10000',
#     'timeInForce': 'GTC',
#     'triggerCondition': 'DEFAULT',
#     'state': 'PENDING'}}],
#  'lastTransactionID': '9'}

# %%
tradeID = r['trades'][0]['id']
tradeID
# Out:
# '5'

# %% [markdown]
# ### Trades Details
# Get the details of a specific Trade in an Account.
#
# [Python-Oanda API-Trades Details](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/trades/tradedetails.html)

# %%
r = api.request(TradeDetails(accountID, tradeID))
r
# Out:
# {'trade': {'id': '5',
#   'instrument': 'EUR_USD',
#   'price': '1.08477',
#   'openTime': '2020-02-21T21:22:10.236098884Z',
#   'initialUnits': '-1',
#   'initialMarginRequired': '0.0217',
#   'state': 'OPEN',
#   'currentUnits': '-1',
#   'realizedPL': '0.0000',
#   'financing': '0.0000',
#   'dividendAdjustment': '0.0000',
#   'unrealizedPL': '-0.0001',
#   'marginUsed': '0.0217',
#   'takeProfitOrder': {'id': '8',
#    'createTime': '2020-02-21T21:53:52.913988823Z',
#    'replacesOrderID': '6',
#    'type': 'TAKE_PROFIT',
#    'tradeID': '5',
#    'price': '0.10000',
#    'timeInForce': 'GTC',
#    'triggerCondition': 'DEFAULT',
#    'state': 'PENDING'}},
#  'lastTransactionID': '9'}

# %% [markdown]
# ## Positions
#
# [Python-Oanda API - Positions](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/positions.html)
#
# - PositionList
# - PositionDetails
# - PositionClose
# - OpenPositions

# %%
from oandapyV20.endpoints.positions import PositionList, PositionDetails

# %% [markdown]
# ### Position List
# List all Positions for an Account. The Positions returned are for every instrument that has had a position during the lifetime of the Account.
#
# [Python-Oanda API-Position List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/positions/positionlist.html)

# %%
r = api.request(PositionList(accountID))
r
# Out:
# {'positions': [{'instrument': 'EUR_USD',
#    'long': {'units': '0',
#     'pl': '0.0000',
#     'resettablePL': '0.0000',
#     'financing': '0.0000',
#     'dividendAdjustment': '0.0000',
#     'guaranteedExecutionFees': '0.0000',
#     'unrealizedPL': '0.0000'},
#    'short': {'units': '-1',
#     'averagePrice': '1.08477',
#     'pl': '0.0000',
#     'resettablePL': '0.0000',
#     'financing': '0.0000',
#     'dividendAdjustment': '0.0000',
#     'guaranteedExecutionFees': '0.0000',
#     'tradeIDs': ['5'],
#     'unrealizedPL': '-0.0001'},
#    'pl': '0.0000',
#    'resettablePL': '0.0000',
#    'financing': '0.0000',
#    'commission': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'guaranteedExecutionFees': '0.0000',
#    'unrealizedPL': '-0.0001',
#    'marginUsed': '0.0217'}],
#  'lastTransactionID': '9'}

# %% [markdown]
# ### Position Details
# Get the details of a single instrument’s position in an Account. The position may be open or not.
#
# [Python-Oanda API-Details List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/positions/positiondetails.html)

# %%
r = api.request(PositionDetails(accountID, "EUR_USD"))
r
# Out:
# {'position': {'instrument': 'EUR_USD',
#   'long': {'units': '0',
#    'pl': '0.0000',
#    'resettablePL': '0.0000',
#    'financing': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'guaranteedExecutionFees': '0.0000',
#    'unrealizedPL': '0.0000'},
#   'short': {'units': '-1',
#    'averagePrice': '1.08477',
#    'pl': '0.0000',
#    'resettablePL': '0.0000',
#    'financing': '0.0000',
#    'dividendAdjustment': '0.0000',
#    'guaranteedExecutionFees': '0.0000',
#    'tradeIDs': ['5'],
#    'unrealizedPL': '-0.0001'},
#   'pl': '0.0000',
#   'resettablePL': '0.0000',
#   'financing': '0.0000',
#   'commission': '0.0000',
#   'dividendAdjustment': '0.0000',
#   'guaranteedExecutionFees': '0.0000',
#   'unrealizedPL': '-0.0001',
#   'marginUsed': '0.0217'},
#  'lastTransactionID': '9'}

# %% [markdown]
# ## Transaction
#
# [Python-Oanda API-Transaction](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/transactions.html)

# %%
from oandapyV20.endpoints.transactions import TransactionList, TransactionDetails

# %% [markdown]
# ### TransactionList
# Get a list of Transactions pages that satisfy a time-based Transaction query.
#
# [Python-Oanda API-Transaction List](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/transactions/transactionlist.html)

# %%
r = api.request(TransactionList(accountID))
r
# Out:
# {'from': '2020-02-21T21:09:09.769110943Z',
#  'to': '2020-02-22T12:27:01.857168010Z',
#  'pageSize': 100,
#  'count': 9,
#  'pages': ['https://api-fxpractice.oanda.com/v3/accounts/101-011-13528713-001/transactions/idrange?from=1&to=9'],
#  'lastTransactionID': '9'}

# %%
transactionID = r['lastTransactionID']
transactionID
# Out:
# '9'

# %% [markdown]
# ### TransactionDetails
# Get the details of a single Account Transaction.
#
# [Python-Oanda API-TransactionDetails](https://oanda-api-v20.readthedocs.io/en/latest/endpoints/transactions/transactiondetails.html)

# %%
r = api.request(TransactionDetails(accountID, transactionID))
r
# Out:
# {'transaction': {'type': 'DAILY_FINANCING',
#   'financing': '0.0000',
#   'accountBalance': '100000.0000',
#   'positionFinancings': [{'instrument': 'EUR_USD',
#     'financing': '0.0000',
#     'accountFinancingMode': 'DAILY_INSTRUMENT',
#     'openTradeFinancings': [{'tradeID': '5', 'financing': '0.0000'}]}],
#   'id': '9',
#   'accountID': '101-011-13528713-001',
#   'userID': 13528713,
#   'batchID': '9',
#   'time': '2020-02-21T22:00:00.000000000Z'},
#  'lastTransactionID': '9'}
